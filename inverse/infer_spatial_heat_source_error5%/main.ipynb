# %%
import torch

from config import Config
from core import Trainer
from utils import _torch_device, _ensure_dirs

def main():
    torch.set_default_dtype(torch.float64)
    cfg = Config()
    print("Using device:", _torch_device())
    _ensure_dirs(cfg)
    trainer = Trainer(cfg)
    trainer.run()


if __name__ == "__main__":
    main()
# Out:
# Using device: cpu
# FC_Net(
#   (net): Sequential(
#     (0): NonLinearLayer(
#       (net): Sequential(
#         (0): Linear(in_features=2, out_features=60, bias=True)
#         (1): Tanh()
#       )
#     )
#     (1): NonLinearLayer(
#       (net): Sequential(
#         (0): Linear(in_features=60, out_features=60, bias=True)
#         (1): Tanh()
#       )
#     )
#     (2): NonLinearLayer(
#       (net): Sequential(
#         (0): Linear(in_features=60, out_features=60, bias=True)
#         (1): Tanh()
#       )
#     )
#     (3): NonLinearLayer(
#       (net): Sequential(
#         (0): Linear(in_features=60, out_features=60, bias=True)
#         (1): Tanh()
#       )
#     )
#     (4): NonLinearLayer(
#       (net): Sequential(
#         (0): Linear(in_features=60, out_features=60, bias=True)
#         (1): Tanh()
#       )
#     )
#     (5): NonLinearLayer(
#       (net): Sequential(
#         (0): Linear(in_features=60, out_features=60, bias=True)
#         (1): Tanh()
#       )
#     )
#     (6): Linear(in_features=60, out_features=2, bias=True)
#   )
# )
# Total params: 18606
# current trial: 1
# epoch 400 | loss 1.143e+02 | obj 5.284e+01 | constraints = 1.432e-01, 1.842e-02, 5.996e-01:   0%| | 462/500000 [23:28<4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <cell line: 16>()
#      13     trainer.run()
#      16 if __name__ == "__main__":
# ---> 17     main()
#
# Input In [1], in main()
#      11 _ensure_dirs(cfg)
#      12 trainer = Trainer(cfg)
# ---> 13 trainer.run()
#
# File ~\AppData\Roaming\MobaXterm\home\capu\1_template_unsteady_heat\core\trainer.py:126, in Trainer.run(self)
#     123     optim = torch.optim.LBFGS(model.parameters(), line_search_fn="strong_wolfe")
#     124     using_lbfgs = True
# --> 126 objective, constr, loss = trainer.step(
#     127     model, optim, state, using_lbfgs, scheduler
#     128 )
#     130 # Logs
#     131 append_logs(epoch, state, objective, constr,
#     132             mu_buf, lambda_buf, obj_buf, constr_buf
#     133 )
#
# File ~\AppData\Roaming\MobaXterm\home\capu\1_template_unsteady_heat\core\pecann.py:49, in PECANNTrainer.step(self, model, optim, state, using_lbfgs, scheduler)
#      47 objective, constr = self.eval_fn(model)
#      48 loss = self.augmented_lagrangian(objective, constr, state)
# ---> 49 loss.backward()
#      50 optim.step()
#      52 # Re-evaluate after step for accurate post-step values
#
# File D:\ProgramData\Anaconda3\lib\site-packages\torch\_tensor.py:396, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     387 if has_torch_function_unary(self):
#     388     return handle_torch_function(
#     389         Tensor.backward,
#     390         (self,),
#    (...)
#     394         create_graph=create_graph,
#     395         inputs=inputs)
# --> 396 torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File D:\ProgramData\Anaconda3\lib\site-packages\torch\autograd\__init__.py:173, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     168     retain_graph = create_graph
#     170 # The reason we repeat same the comment below is that
#     171 # some Python versions print out the first line of a multi-line function
#     172 # calls in the traceback and some print out the last line
# --> 173 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     175     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:
