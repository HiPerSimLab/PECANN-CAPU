# %%
import torch

from config import Config
from core.trainer import Trainer
from utils.utils import _torch_device, _ensure_dirs

def main():
    torch.set_default_dtype(torch.float64)
    cfg = Config()
    print("Using device:", _torch_device())
    _ensure_dirs(cfg)
    trainer = Trainer(cfg)
    trainer.run()


if __name__ == "__main__":
    main()
# Out:
# Using device: cpu
# SpatialNet(
#   (net): Sequential(
#     (0): NonLinearLayer(
#       (net): Sequential(
#         (0): Linear(in_features=2, out_features=40, bias=True)
#         (1): Tanh()
#       )
#     )
#     (1): NonLinearLayer(
#       (net): Sequential(
#         (0): Linear(in_features=40, out_features=40, bias=True)
#         (1): Tanh()
#       )
#     )
#     (2): NonLinearLayer(
#       (net): Sequential(
#         (0): Linear(in_features=40, out_features=40, bias=True)
#         (1): Tanh()
#       )
#     )
#     (3): Linear(in_features=40, out_features=1, bias=True)
#   )
# )
# Total params: 3445
# current trial: 1
# epoch 1000 | loss 8.349e-01 | obj 7.470e-01 | constraints = 8.434e-02:   2%|    | 999/50000 [23:20<18:44:46,  1.38s/it]rela. l2 norm = 1.772e-01, linf norm = 1.190e+00
# epoch 2000 | loss 5.348e-01 | obj 3.992e-01 | constraints = 1.087e-03:   4%|   | 1999/50000 [46:38<19:39:37,  1.47s/it]rela. l2 norm = 1.501e-02, linf norm = 1.134e-01
# ...
