# %%
import torch

from config import Config
from core import Trainer
from utils import _torch_device, _ensure_dirs

def main():
    torch.set_default_dtype(torch.float64)
    cfg = Config()
    print("Using device:", _torch_device())
    _ensure_dirs(cfg)
    trainer = Trainer(cfg)
    trainer.run()


if __name__ == "__main__":
    main()
# Out:
# Using device: cpu
# FC_Net(
#   (net): Sequential(
#     (0): NonLinearLayer(
#       (net): Sequential(
#         (0): Linear(in_features=2, out_features=60, bias=True)
#         (1): Tanh()
#       )
#     )
#     (1): NonLinearLayer(
#       (net): Sequential(
#         (0): Linear(in_features=60, out_features=60, bias=True)
#         (1): Tanh()
#       )
#     )
#     (2): NonLinearLayer(
#       (net): Sequential(
#         (0): Linear(in_features=60, out_features=60, bias=True)
#         (1): Tanh()
#       )
#     )
#     (3): NonLinearLayer(
#       (net): Sequential(
#         (0): Linear(in_features=60, out_features=60, bias=True)
#         (1): Tanh()
#       )
#     )
#     (4): NonLinearLayer(
#       (net): Sequential(
#         (0): Linear(in_features=60, out_features=60, bias=True)
#         (1): Tanh()
#       )
#     )
#     (5): NonLinearLayer(
#       (net): Sequential(
#         (0): Linear(in_features=60, out_features=60, bias=True)
#         (1): Tanh()
#       )
#     )
#     (6): Linear(in_features=60, out_features=2, bias=True)
#   )
# )
# Total params: 18606
# current trial: 1
# epoch 400 | loss 1.143e+02 | obj 5.284e+01 | constraints = 1.432e-01, 1.842e-02, 5.996e-01:   0%| | 448/500000 [22:52<4
